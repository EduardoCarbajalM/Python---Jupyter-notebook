# %%
import matplotlib.pyplot as plt
import pandas as pd

datos_marketing = {
    "Gasto_Publicidad_USD": [50, 60, 80, 100, 120, 150, 180, 200, 220, 250],
    "Clics_Obtenidos": [120, 140, 155, 190, 210, 260, 310, 330, 360, 400]
}
df_ads = pd.DataFrame(datos_marketing)

df_ads
# Out:
#    Gasto_Publicidad_USD  Clics_Obtenidos
# 0                    50              120
# 1                    60              140
# 2                    80              155
# 3                   100              190
# 4                   120              210
# 5                   150              260
# 6                   180              310
# 7                   200              330
# 8                   220              360
# 9                   250              400

# %%
plt.scatter(df_ads['Gasto_Publicidad_USD'], df_ads['Clics_Obtenidos'])
plt.title('Impacto de la Inversion Publicitaria')
plt.xlabel('Gasto en publicidad (USD)')
plt.ylabel('Clics obtenidos')
plt.show()
