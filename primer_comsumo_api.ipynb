# %%
# Simulamos la respuesta JSON de la API
datos_bitcoin = {
    "time": {
        "updated": "Aug 26, 2026 12:00:00 UTC"
    },
    "bpi": {
        "USD": {
            "code": "USD",
            "rate": "65,432.10",
            "description": "United States Dollar",
            "rate_float": 65432.10
        },
        "EUR": {
            "code": "EUR",
            "rate": "59,123.45",
            "description": "Euro",
            "rate_float": 59123.45
        }
    }
}

# %%
precio_actual = datos_bitcoin['bpi']['USD']['rate_float']

precio_actual
# Out:
# 65432.1
