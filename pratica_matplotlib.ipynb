# %%
import matplotlib.pyplot as plt
import pandas as pd

# Los datos limpios que calculaste en tu proyecto anterior
resumen_trimestre = {
    "Mes": ["Enero", "Febrero", "Marzo"], 
    "Ventas_Totales": [3800.0, 3900.0, 5700.0]
}
df_reporte = pd.DataFrame(resumen_trimestre)

df_reporte
# Out:
#        Mes  Ventas_Totales
# 0    Enero          3800.0
# 1  Febrero          3900.0
# 2    Marzo          5700.0

# %%
plt.plot(df_reporte['Mes'],df_reporte['Ventas_Totales'], marker='o')
plt.title('Crecimiento de Ventas Q1')
plt.xlabel('Meses')
plt.ylabel('Ingresos (USD)')
plt.show()
